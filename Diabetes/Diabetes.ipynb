# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes

# %%
data = load_diabetes(as_frame=True)

# %%
df = data.frame

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
# features are scaled so there is no need to scaler the features before train and test split
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
df.isnull().sum()
# Out:
# age       0
# sex       0
# bmi       0
# bp        0
# s1        0
# s2        0
# s3        0
# s4        0
# s5        0
# s6        0
# target    0
# dtype: int64

# %%
# no null values
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.268604e-17  1.130318e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260971e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324559e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947171e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243232e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335973e-01  1.356118e-01
#
#            target
# count  442.000000
# mean   152.133484
# std     77.093005
# min     25.000000
# 25%     87.000000
# 50%    140.500000
# 75%    211.500000
# max    346.000000

# %%
df["target"]
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 442, dtype: float64

# %%
X = df.drop("target", axis=1)
y = df["target"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=69)

# %%
X_train
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 384  0.034443  0.050680 -0.029918  0.004658  0.093372  0.086994  0.033914
# 200  0.056239 -0.044642 -0.057941 -0.007977  0.052093  0.049103  0.056003
# 197  0.048974  0.050680  0.003494  0.070072 -0.008449  0.013404 -0.054446
# 341  0.030811  0.050680  0.059541  0.056301 -0.022208  0.001191 -0.032356
# 135 -0.005515 -0.044642  0.056307 -0.036656 -0.048351 -0.042963 -0.072854
# ..        ...       ...       ...       ...       ...       ...       ...
# 404 -0.016412 -0.044642  0.054152  0.070072 -0.033216 -0.027931  0.008142
# 90   0.012648 -0.044642 -0.025607 -0.040099 -0.030464 -0.045155  0.078093
# 107  0.027178 -0.044642  0.049840 -0.055006 -0.002945  0.040648 -0.058127
# 203 -0.001882  0.050680  0.030440  0.052858  0.039710  0.056619 -0.039719
# 54  -0.049105 -0.044642  0.025051  0.008101  0.020446  0.017788  0.052322
#
#            s4        s5        s6
# 384 -0.002592  0.024055 -0.038357
# 200 -0.021412 -0.028323  0.044485
# 197  0.034309  0.013317  0.036201
# 341 -0.002592 -0.024795 -0.017646
# 135  0.037999  0.050782  0.056912
# ..        ...       ...       ...
# 404 -0.039493 -0.027129 -0.009362
# 90  -0.076395 -0.072133  0.011349
# 107  0.052759 -0.052963 -0.005220
# 203  0.071210  0.025395  0.027917
# 54  -0.039493 -0.041176  0.007207
#
# [353 rows x 10 columns]

# %%
y_train
# Out:
# 384     69.0
# 200    158.0
# 197    129.0
# 341    263.0
# 135    272.0
#        ...
# 404    293.0
# 90      98.0
# 107    144.0
# 203    222.0
# 54     182.0
# Name: target, Length: 353, dtype: float64

# %%
# fitting the model
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([  22.24202262, -231.36985485,  555.90429421,  311.15508347,
#        -787.78424021,  529.82081059,   81.70825106,  128.29784153,
#         728.05708514,   60.38435804])

# %%
lr.intercept_
# Out:
# np.float64(154.33052417489327)

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([177.39124321, 128.26079805, 174.24662329, 191.72793591,
#        174.92685112, 174.66693803, 169.90741306, 145.18921879,
#        155.7495216 ,  78.00757732, 168.08715987, 114.50337206,
#        175.55153417,  55.63233369, 144.85119876, 165.87371357,
#         57.8887337 , 165.60352764, 104.04145005, 108.80037651,
#         69.97334623, 105.98380805, 183.20405456, 159.09080533,
#         67.99413236, 159.46969573, 136.71845708, 247.05881391,
#        226.24476813,  94.41511262,  80.34103531, 193.95881995,
#        118.03565514, 197.72072246, 159.27108798,  88.59169359,
#        218.13331384, 163.22330369, 148.72805571, 140.85272675,
#        103.70182184, 182.79480312, 264.95322684, 208.72036922,
#         78.11698178, 175.33781443, 101.12932208, 118.19927846,
#        187.16459794, 156.42827605, 178.27136081, 177.45738541,
#        154.75656445,  77.67210844, 215.05758642, 122.80818149,
#        135.80325807, 237.19261749, 139.28074308, 160.8545858 ,
#        200.26624484, 182.10200239, 253.39361864, 121.33880097,
#         93.10131678, 108.7120698 , 102.54289031, 283.92626324,
#        212.40142221, 196.88325675, 190.61663256, 122.38719475,
#        174.84932672, 163.89586471,  76.87985247,  79.16005391,
#        142.55274799, 172.80013687, 254.11182146, 187.14229406,
#        188.68162674, 244.19206435, 102.03396883, 147.68076433,
#        119.78567856,  69.50004844, 151.85099773, 192.8789816 ,
#         75.80593124])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("RMSE:", rmse)
print("R²:", r2)
# Out:
# MAE: 38.91450652245992
# RMSE: 46.940575904238976
# R²: 0.5144740473918747

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred, color="royalblue", alpha=0.7)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    color="red",
    linestyle="--",
    label="Perfect prediction"
)

plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values")
plt.legend()
plt.show()
